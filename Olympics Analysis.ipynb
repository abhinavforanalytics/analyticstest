# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\91973\Downloads\Ex_Files_Pandas_EssT\Ex_Files_Pandas_EssT\ExerciseFiles\data\olympics.csv')

# %%
#Listing all current columns
df.columns
# Out:
# Index(['List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
#Getting rid of the top unwanted rows
df = df[3:]

# %%
df.head()
# Out:
#   List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 3                                               City
# 4                                             Athens
# 5                                             Athens
# 6                                             Athens
# 7                                             Athens
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3    Edition      Sport  Discipline             Athlete        NOC     Gender
# 4       1896   Aquatics    Swimming       HAJOS, Alfred        HUN        Men
# 5       1896   Aquatics    Swimming    HERSCHMANN, Otto        AUT        Men
# 6       1896   Aquatics    Swimming   DRIVAS, Dimitrios        GRE        Men
# 7       1896   Aquatics    Swimming  MALOKINIS, Ioannis        GRE        Men
#
#                    Unnamed: 7    Unnamed: 8 Unnamed: 9
# 3                       Event  Event_gender      Medal
# ...

# %%
#Promoting first row as headers
new_header = df.iloc[0]
df.columns = new_header

# %%
df.head()
# Out:
# 3    City  Edition     Sport  Discipline             Athlete  NOC  Gender  \
# 3    City  Edition     Sport  Discipline             Athlete  NOC  Gender
# 4  Athens     1896  Aquatics    Swimming       HAJOS, Alfred  HUN     Men
# 5  Athens     1896  Aquatics    Swimming    HERSCHMANN, Otto  AUT     Men
# 6  Athens     1896  Aquatics    Swimming   DRIVAS, Dimitrios  GRE     Men
# 7  Athens     1896  Aquatics    Swimming  MALOKINIS, Ioannis  GRE     Men
#
# 3                       Event  Event_gender   Medal
# 3                       Event  Event_gender   Medal
# 4              100m freestyle             M    Gold
# 5              100m freestyle             M  Silver
# 6  100m freestyle for sailors             M  Bronze
# 7  100m freestyle for sailors             M    Gold

# %%
#Getting rid of the top row that replaced the header
df = df[1:]

# %%
df
# Out:
# 3         City Edition      Sport       Discipline               Athlete  NOC  \
# 4       Athens    1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# 5       Athens    1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 6       Athens    1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 7       Athens    1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 8       Athens    1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...        ...     ...        ...              ...                   ...  ...
# 29215  Beijing    2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# 29216  Beijing    2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# 29217  Beijing    2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# 29218  Beijing    2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# 29219  Beijing    2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29215 entries, 5 to 29219
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29215 non-null  object
#  1   Edition       29215 non-null  object
#  2   Sport         29215 non-null  object
#  3   Discipline    29215 non-null  object
#  4   Athlete       29215 non-null  object
#  5   NOC           29215 non-null  object
#  6   Gender        29215 non-null  object
#  7   Event         29215 non-null  object
#  8   Event_gender  29215 non-null  object
#  9   Medal         29215 non-null  object
# dtypes: object(10)
# memory usage: 2.2+ MB

# %%
#Fixing the index misplaced
df.reset_index(inplace=True,drop=True)

# %%
#Reset index name - To make data look more consistent and avoid conflicts with row index numbers
df.rename_axis(None,axis=1,inplace=True)

# %%
df
# Out:
#           City Edition      Sport       Discipline                Athlete  \
# 0       Athens    1896   Aquatics         Swimming       HERSCHMANN, Otto
# 1       Athens    1896   Aquatics         Swimming      DRIVAS, Dimitrios
# 2       Athens    1896   Aquatics         Swimming     MALOKINIS, Ioannis
# 3       Athens    1896   Aquatics         Swimming     CHASAPIS, Spiridon
# 4       Athens    1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# ...        ...     ...        ...              ...                    ...
# 29210  Beijing    2008  Wrestling  Wrestling Gre-R         ENGLICH, Mirko
# 29211  Beijing    2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas
# 29212  Beijing    2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri
# 29213  Beijing    2008  Wrestling  Wrestling Gre-R          LOPEZ, Mijain
# 29214  Beijing    2008  Wrestling  Wrestling Gre-R         BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
#Gender and Event_Gender are identical, hence dropping one
df.drop(columns='Event_gender',inplace=True)
# Out:
# C:\Users\91973\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Get all datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29215 entries, 0 to 29214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29215 non-null  object
#  1   Edition     29215 non-null  object
#  2   Sport       29215 non-null  object
#  3   Discipline  29215 non-null  object
#  4   Athlete     29215 non-null  object
#  5   NOC         29215 non-null  object
#  6   Gender      29215 non-null  object
#  7   Event       29215 non-null  object
#  8   Medal       29215 non-null  object
# dtypes: object(9)
# memory usage: 2.0+ MB

# %%
df.rename(columns={'Edition':'Year'},inplace=True) #Renaming to year for consistency
# Out:
# C:\Users\91973\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head()
# Out:
#      City  Year     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens  1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 1  Athens  1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 2  Athens  1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 3  Athens  1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 4  Athens  1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
#
#                         Event   Medal
# 0              100m freestyle  Silver
# 1  100m freestyle for sailors  Bronze
# 2  100m freestyle for sailors    Gold
# 3  100m freestyle for sailors  Silver
# 4             1200m freestyle  Bronze

# %%
df['Year']=pd.to_datetime(df['Year'],format='%Y') #Changing it to date format
# Out:
# C:\Users\91973\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Year']=df['Year'].dt.year #extracting Year after transformation
# Out:
# C:\Users\91973\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
graph = sns.FacetGrid(df,col='Medal',hue='Gender',margin_titles=True,despine=True)
graph.map(sns.barplot,'Gender')
graph.add_legend()
# Out:
# C:\Users\91973\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-f0cc4da2fd96> in <module>
#       1 graph = sns.FacetGrid(df,col='Medal',hue='Gender',margin_titles=True,despine=True)
# ----> 2 graph.map(sns.barplot,'Gender')
#       3 graph.add_legend()
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
#     769         # Finalize the annotations and layout
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     849
#     850         # Draw the plot
# ...
